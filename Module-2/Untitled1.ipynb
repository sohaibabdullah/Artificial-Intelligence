# %%
import numpy as np
X = np.zeros((3,2))

# %%
X
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
import matplotlib.pyplot as plt
plt.scatter(2,3)

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])
